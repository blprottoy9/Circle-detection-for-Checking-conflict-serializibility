# %%
import pydot
import os
import IPython
from IPython.display import Image, display
class Stack():
	def __init__(self):
		self.items=[]
	def push(self,item):
		self.items.append(item)
	def pop(self):
		return self.items.pop()
	def is_empty(self):
		return self.items==[]
	def top(self):
		if not self.is_empty():
			return self.items[-1]
	def get_stack(self):
		return self.items
'''s=Stack()
s.push('a')
s.push('b')
print(s.get_stack())
#s.pop()
print(s.top())'''
#import number
def gra(G):
	g=pydot.Dot(graph_type="digraph")
	for i in G:
		node=pydot.Node(i[-1],style="filled",fillcolor="green")
		g.add_node(node)
		print(i)
	im=Image(g.create_png())
	display(im)
	
	
	return
	
def DFS(G,S):
	s1=Stack()
	s1.push(s)
	
	return
def main():
	f1=open('a.txt')

# %%
import pydot
import os
import IPython
from IPython.display import Image, display
class Stack():
	def __init__(self):
		self.items=[]
	def push(self,item):
		self.items.append(item)
	def pop(self):
		return self.items.pop()
	def is_empty(self):
		return self.items==[]
	def top(self):
		if not self.is_empty():
			return self.items[-1]
	def get_stack(self):
		return self.items
'''s=Stack()
s.push('a')
s.push('b')
print(s.get_stack())
#s.pop()
print(s.top())'''
#import number
def gra(G):
	g=pydot.Dot(graph_type="digraph")
	for i in G:
		node=pydot.Node(i[-1],style="filled",fillcolor="green")
		g.add_node(node)
		print(i)
	im=Image(g.create_png())
	display(im)
	
	
	return
	
def DFS(G,S):
	s1=Stack()
	s1.push(s)
	
	return
def main():
	f1=open('a.txt').read().split('\n')
	del f1[len(f1)-1]
